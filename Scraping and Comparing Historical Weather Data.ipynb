# %% [markdown]
# # Hypothesis:
# This hypothesis was issued by the "Statistical Institute Alina Steinmetz" (my wife) and is being preached since we moved from Moscow to Berlin many years ago (in 2011). It is time to examine the truthfulness of this hypothesis:
#
#     "Berlin summers are most of the time much colder than in Moscow. Berlin is much more mild over the year but the summers in Moscow are hotter."
#
# # First Try
# When searching for data I encountered that there are of course a lot of statistics out there already and decided that it wouldn't make sense for me to work with something that was visualized and depicted 1000 times before. So I just got 3 comparing statistics from the German weather website http://www.wetteronline.de/klima-temperatur/berlin
# , showed them to my wife and explained that when comparing the graphs she will see that...
# <br><br>
# <i> [To be able to follow this tutorial, you will have to install python(3.x), IPython, jupyter and later we have to add some other libraries (I recommend to use [anaconda](https://www.continuum.io/downloads), then you'll have all bundled up and the setup of other libraries will be just one line of code). This guide is really step by step, how I approached the problem from Zero to Goal. I think it's good for scraping beginners. Let me know if there are any problems with the code or anything else. ]</i>
# <br>
# <br>
# <i>(to navigate between the cells, click on a cell once and do follow with SHIFT+ENTER on your keyboard)</i>
# <br>

# %% [markdown]
# ### ... Berlin is slightly warmer in June and August:

# %% [markdown]
# ![temperature comparison](https://raw.githubusercontent.com/RichStone/weather-comparison-berlin-moscow/master/temperature.png)

# %% [markdown]
# ### ... Berlin is less rainy:

# %% [markdown]
# ![temperature comparison](https://raw.githubusercontent.com/RichStone/weather-comparison-berlin-moscow/master/rain.png)

# %% [markdown]
# ### ... Berlin is more windy:

# %% [markdown]
# ![temperature comparison](https://raw.githubusercontent.com/RichStone/weather-comparison-berlin-moscow/master/wind.png)

# %% [markdown]
# I was convinced that this little presentation would be enough for every sane person to accept that Moscow's summer is not really a lot more hotter than Berlin's (only less windy).
#
# My wife wasn't really happy, though. She replied, that she doesn't know where the statistics come from and what period this is. In fact I realized that I broke [one of the basics](https://medium.com/data-goodie/data-scientists-exercise-with-their-own-ideas-on-real-datasets-basics-for-starting-out-with-them-c7d4dad98f4b) when starting out with any statistic or data: Expressiveness. I was not sure which period of time those graphs covered and it's not stated there either. I just said some years... But was it the same amount of time? And who cares about 150 year old data anyway? Also 200 years ago part of Western Europe experienced a minor Ice Age (https://en.wikipedia.org/wiki/Little_Ice_Age), is that taken in the account of Berlin too :D ? So I decided to make my own statistics for some relevant period of time. Firstly, I would take the data from the last 25 years to show the hypothesis' general fallacy. And secondly, examine closely the periods when Mrs. Steinmetz lived in Moscow and when she moved to Berlin to check if there might be some evidence for a little bias.
#
# # Weather data
# Getting some historical weather data of Moscow and Berlin wasn't as a funny walk as I thought it would be.
# I found the raw datasets to be super cryptic and the explanatory codebooks non-existent or non-sense. When I found some really good looking data on www.wetteronline.de I was very happy as it seemed to be a doable task to get it with a few scraping tricks using python. The data is nicely organzed in tables and the URLs give readable information [(link)](http://www.wetteronline.de/?pcid=pc_rueckblick_climate&gid=10382&iid=10382&pid=p_rueckblick_climatecalculator&sid=Default&var=TX&analysis=monthly&month=08&startyear=1990&endyear=2017&iid=10382):

# %% [markdown]
# ![temperature comparison](https://raw.githubusercontent.com/RichStone/weather-comparison-berlin-moscow/master/example-data-table.png)

# %% [markdown]
# # Getting the Data - Scrape it out
# Scrape sounds very cruel. But actually the process of web scraping having some programming experience isn't that bad.
#
# I outlined the following plan to reach my goal:
#
# Print all weather data of the www.wetteronline.de page for Moscow and Berlin. (7 categories [like highest average temperature etc.] for every month from 01.1990 to 07.2017)
# <br>
# <br>
# Next tutorials will then be about putting the data into a database, analyzing/comparing/visualizing it and finally we might touch on some machine learning to see if we get any fancy predictions of weather based on historical data.

# %% [markdown]
# # - I. -
# Task 1: Print out Moscow's average highest temperature for August for all years between 1990 and 2017 with the data gathered from the website.

# %%
# Libraries
# I already knew where to begin thanks to my Professor Zhang, who was brave enough
# to start out our computer science course with some nice practical scraping.
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
# if you don't have BeautifulSoup installed yet, you would need to do in your
# command line: pip install beautifulsoup4

# %%
# declare variables and load page
req = Request('http://www.wetteronline.de/?pcid=pc_rueckblick_climate&gid=27612&iid=27612&pid=p_rueckblick_climatecalculator&sid=Default&var=TX&analysis=monthly&month=08&startyear=1990&endyear=2017&iid=27612', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()

# %% [markdown]
# By the way my first approach failed with the error
# <br>
#   <b>"HTTPError: HTTP Error 403: Forbidden"</b>
# <br>
# The solution was to put the header as the last parameter of the Request() object so that our request wouldn't be classified as some evil robotic force crawling the website.

# %% [markdown]
# The second approach with the header passed to the Request was then more successful with this Beautiful Output:

# %%
print(webpage)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n \n <title>Klima in der Region Moskau - Klimarechner - WetterOnline</title>\n <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n <meta name="description" content="Wie war das Klima in der Region Moskau? Mit dem Klimarechner k&ouml;nnen Sie historische Werte ermitteln." />\n <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n <meta http-equiv="content-language" content="de-DE" />\n \n  <meta property="fb:admins" content="100001020190994" />\n <meta property="fb:admins" content="1060016694" />\n\n <meta property="og:title" content="Klima in der Region Moskau - Klimarechner - WetterOnline">\n <meta property="og:type" content="article">\n  <meta name="viewport" content="width=1160">\n <meta property="og:image" content="https://st.wetteronline.de/dr/1.0.800/images/logo/ogimage_wetteronline_1200x630.png">\n \n <meta name="skype_toolbar" content="skype_toolbar_parser_compatible" />\n<meta name="msapplication-TileColor" content="#ffffff"/>\n<meta name="msapplication-TileImage" content="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png"/>\n<meta name="apple-itunes-app" content="app-id=545993260">\n<meta name="google-play-app" content="app-id=de.wetteronline.wetterapp" data-app-name="WetterOnline App" data-app-icon="https://st.wetteronline.de/dr/1.0.800/images/icon/appicon_wetterapp_192x192.png" data-app-linktext="zur App&hellip;">\n<meta name="twitter:widgets:csp" content="on">\n<meta name="theme-color" content="#10658e">\n<link rel="search" type="application/opensearchdescription+xml" title="WetterOnline" href="https://st.wetteronline.de/wetteronline-search.xml" />\n<link rel="publisher" href="https://plus.google.com/108164279989314748748/" />\n<link rel="shortcut icon" type="image/x-icon" href="https://st.wetteronline.de/dr/1.0.800/images/logo/favicon.ico" />\n<link rel="apple-touch-icon" href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png" sizes="180x180" />\n<link rel="apple-touch-icon" href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_152x152.png" sizes="152x152" />\n<link rel="apple-touch-icon" href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_120x120.png" sizes="120x120" />\n<link rel="apple-touch-icon" href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_76x76.png" sizes="76x76" />\n<script type="application/ld+json">\n{ \n "@context" : "http://schema.org",  \n "@type" : "Organization",  \n "name" : "WetterOnline",  \n "url" : "https://wo.wetteronline.de",  \n "logo": "https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png", \n "sameAs" : [     \n  "https://www.facebook.com/wetteronline",    \n  "https://twitter.com/wetteronline",\t\n  "https://www.youtube.com/user/WetterOnlineGmbH",     \n  "https://plus.google.com/u/0/+wetteronline",\t\n  "https://instagram.com/wetteronline/"\t\n ] \n}\n</script>\n\n <meta property="og:url" content="http://www.wetteronline.de/?pcid=pc_rueckblick_climate&amp;gid=27612&amp;pid=p_rueckblick_climatecalculator&amp;sid=Default&amp;iid=27612">\n <meta property="og:description" content="Wie war das Klima in der Region Moskau? Mit dem Klimarechner k&ouml;nnen Sie historische Werte ermitteln.">\n <meta property="og:locale" content="de_DE">\n <meta property="og:site_name" content="WetterOnline">\n <meta name="application-name" content="Klima in der Region Moskau - Klimarechner - WetterOnline"/>\n <link rel="canonical" href="http://www.wetteronline.de/?pcid=pc_rueckblick_climate&amp;gid=27612&amp;pid=p_rueckblick_climatecalculator&amp;sid=Default&amp;iid=27612">\n\n  <link href="https://st.wetteronline.de/dr/1.0.800/css/wetteronline.css" rel="stylesheet" media="screen" />\n  <link href="https://st.wetteronline.de/dr/1.0.800/css/pc_rueckblick_climate.css" rel="stylesheet" media="screen" type="text/css" />\n\n <link href="https://st.wetteronline.de/dr/1.0.800/css/print.css" rel="stylesheet" media="print" />\n <link rel="stylesheet" media="only screen and  ...

# %% [markdown]
# ### Make a soup out of it
# But you can make this output even more precious. The beautifulsoup library is very popular to convert ugly things in nice readable structures. As you can see at the beginning of the output above, it starts with some <b>b'</b>. That is a sign for the fact that it is a byte string which has to be decoded first:

# %%
webpage = webpage.decode('utf-8')

# %% [markdown]
# Now you are ready to really make it a readable output using the prettify() method on our soup:

# %%
soup = bs(webpage, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Klima in der Region Moskau - Klimarechner - WetterOnline
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="Wie war das Klima in der Region Moskau? Mit dem Klimarechner können Sie historische Werte ermitteln." name="description"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="de-DE" http-equiv="content-language"/>
#   <meta content="100001020190994" property="fb:admins"/>
#   <meta content="1060016694" property="fb:admins"/>
#   <meta content="Klima in der Region Moskau - Klimarechner - WetterOnline" property="og:title">
#    <meta content="article" property="og:type">
#     <meta content="width=1160" name="viewport">
#      <meta content="https://st.wetteronline.de/dr/1.0.800/images/logo/ogimage_wetteronline_1200x630.png" property="og:image">
#       <meta content="skype_toolbar_parser_compatible" name="skype_toolbar"/>
#       <meta content="#ffffff" name="msapplication-TileColor"/>
#       <meta content="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png" name="msapplication-TileImage"/>
#       <meta content="app-id=545993260" name="apple-itunes-app">
#        <meta content="app-id=de.wetteronline.wetterapp" data-app-icon="https://st.wetteronline.de/dr/1.0.800/images/icon/appicon_wetterapp_192x192.png" data-app-linktext="zur App…" data-app-name="WetterOnline App" name="google-play-app">
#         <meta content="on" name="twitter:widgets:csp">
#          <meta content="#10658e" name="theme-color">
#           <link href="https://st.wetteronline.de/wetteronline-search.xml" rel="search" title="WetterOnline" type="application/opensearchdescription+xml"/>
#           <link href="https://plus.google.com/108164279989314748748/" rel="publisher"/>
#           <link href="https://st.wetteronline.de/dr/1.0.800/images/logo/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#           <link href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#           <link href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#           <link href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#           <link href="https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#           <script type="application/ld+json">
#            {
#  "@context" : "http://schema.org",
#  "@type" : "Organization",
#  "name" : "WetterOnline",
#  "url" : "https://wo.wetteronline.de",
#  "logo": "https://st.wetteronline.de/dr/1.0.800/images/logo/woicon_180x180.png",
#  "sameAs" : [
#   "https://www.facebook.com/wetteronline",
#   "https://twitter.com/wetteronline",
#   "https://www.youtube.com/user/WetterOnlineGmbH",
#   "https://plus.google.com/u/0/+wetteronline",
#   "https://instagram.com/wetteronline/"
#  ]
# }
#           </script>
#           <meta content="http://www.wetteronline.de/?pcid=pc_rueckblick_climate&amp;gid=27612&amp;pid=p_rueckblick_climatecalculator&amp;sid=Default&amp;iid=27612" property="og:url">
#            <meta content="Wie war das Klima in der Region Moskau? Mit dem Klimarechner können Sie historische Werte ermitteln." property="og:description">
#             <meta content="de_DE" property="og:locale">
#              <meta content="WetterOnline" property="og:site_name">
#               <meta content="Klima in der Region Moskau - Klimarechner - WetterOnline" name="application-name"/>
#               <link href="http://www.wetteronline.de/?pcid=pc_rueckblick_climate&amp;gid=27612&amp;pid=p_rueckblick_climatecalculator&amp;sid=Default&amp;iid=27612" rel="canonical">
#                <link href="https://st.wetteronline.de/dr/1.0.800/css/wetteronline.css" media="screen" rel="stylesheet"/>
#                <link href="https://st.wetteronline.de/dr/1.0.800/css/pc_rueckblick_climate.css" media="screen" rel="stylesheet" type="text/css"/>
#                <link href="https://st.wetteronline.de/dr/1.0.800/css/print.css" media="print" rel="stylesheet"/>
#                <link href="https://st.wetteronline.de/dr/1.0.800/css/ipad.css" media="only screen and (max-device-width: 1024px)" rel="stylesheet"/>
#                <script src="https://st.wetteronline.de/dr/1.0.800/js/lib/mootools/library-1.4.5-1.4.0.1.js" type="text/javascript">
#                </script>
#                <script src="https://st.wetteronline.de/dr/1.0.800/js/tt.js" type="text/javascript">
#                </script>
#                <script type="text/javascript">
#                 if (!WO) var WO = {}; // @namespace
#   WO.version = "1.0.800";
#   WO.system = "";
#   WO.region = "de";
#   WO.application = "www";
#   WO.initialized = {};
#   dataLayer = [{
#       'WO.application': 'www'
#   }];
#                </script>
#                <script src="https://st.wetteronline.de/dr/1.0.800/js/strings.de.js" type="text/javascript">
#                </script>
#                <script type="text/javascript">
#                 WO.user = {action : false, loggedin: false, level: "free"};
#   WO.cookie = {};
#                </script>
#                <!-- ((DEBUG_TREE_JS)) -->
#                <script type="text/javascript">
#                 // init content-Variablen Container
# WO.c = {
# 	mc   : { cur: ""},
# 	pcid : { cur: "pc_rueckblick_climate"},
# 	pid  : { def: "p_rueckblick_climatediagram"},
# 	sid  : { def: "Temperature",
# 		 cur: "Default"},
# 	iid  : { def: "27612",
# 	         allowed: {
#                   "p_rueckblick_climatediagram": {"Temperature": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208'],"Wind": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208'],"Precipitation": ['27612','27402','27719','26499','26695','27707','27208']},"p_rueckblick_travelplanner": {"Default": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208']},"p_rueckblick_climatehistory": {"Temperature": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208'],"Wind": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208'],"Precipitation": ['27612','27402','27719','26499','26695','27707','27208']},"p_rueckblick_climatecalculator": {"Default": ['27612','27402','27719','27532','27730','26499','27329','26695','27707','27208']},"p_rueckblick_requestedclimate": {"Default": ['Wunschklima']},"p_rueckblick_colormap": {"ColorMap": ['euro']}
# 	         }
#         }
#        };
# WO.geo = {
# 	alt : 160,
# 	gid : "27612",
# 	lat : 55.7500,
# 	homemark: false,
# 	locationname : "Moskau",
# 	locationname_long: "Moskau",
# 	sublocationname : "",
# 	nogid: false,
# 	subgid: false,
# 	lon : 37.6167,
# 	statename : "",
# 	stateid : "",
# 	path: "euro;Europa;Europa$0005;Osteuropa;Osteuropa$RS;Russland;Russland$27612;Moskau;Moskau$"
# };
# WO.date = {};
# WO.strings.geoinfo = "Geo- &amp; Astro-Infos f&uuml;r Moskau";
#                </script>
#                <script src="https://st.wetteronline.de/dr/1.0.800/js/base64.2.js" type="text/javascript">
#                </script>
#                <script src="https://st.wetteronline.de/dr/1.0.800/js/wetteronline.js" type="text/javascript">
#                </script>
#                <script type="text/javascript">
#                 var crtg_nid = '3309', crtg_cookiename = 'crtg_rta', crtg_varname = 'crtg_rta_content';
# function crtg_getCookie(c_name){ var i,x,y,ARRCookies=document.cookie.split(";");for(i=0;i<ARRCookies.length;i++){x=ARRCookies[i].substr(0,ARRCookies[i].indexOf("="));y=ARRCookies[i].substr(ARRCookies[i].indexOf("=")+1);x=x.replace(/^\s+|\s+$/g,"");if(x==c_name){return unescape(y);} }return'';}
# var crtg_rta_content = crtg_getCookie(crtg_cookiename), crtg_rnd=Math.floor(Math.random()*99999999999);
# (function(){
#  var crtg_url=location.protocol+'//rtax.criteo.com/delivery/rta/rta.js?netId='+escape(crtg_nid); crtg_url +='&cookieName='+escape(crtg_cookiename); crtg_url +='&rnd='+crtg_rnd; crtg_url +='&varName=' + escape(crtg_varname);
#  var crtg_script=document.createElement('script'); crtg_script.type='text/javascript'; crtg_script.src=crtg_url; crtg_script.async=true;
#  if(document.getElementsByTagName("head").length>0)document.getElementsByTagName("head")[0].appendChild(crtg_script); else if(document.getElementsByTagName("body").length>0)document.getElementsByTagName("body")[0].appendChild(crtg_script);
# })();
#                </script>
#                <!-- no context vars -->
#                <link href="https://cnt.wetteronline.de/cgi-bin/ivw/CP/cnt.css?start_head" media="screen" rel="stylesheet" type="text/css"/>
#                <script src="//c.amazon-adsystem.com/aax2/amzn_ads.js" type="text/javascript">
#                </script>
#                <script type="text/javascript">
#                 try {
#         amznads.getAds('3489');
#     } catch(e) { /*ignore*/}
#                </script>
#                <script src="https://st.wetteronline.de/wodas/static/showAds.js" type="text/javascript">
#                </script>
#                <link href="https://st.wetteronline.de/dr/1.0.800/css/www.css" media="screen" rel="stylesheet" type="text/css"/>
#                <script type="text/javascript">
#                 var contentSrc = WO.c.pid.cur;
#   if(typeof contentSrc == 'undefined')
#   {
#     contentSrc = WO.c.pid.def;
#   }
#                </script>
#                <script src="//wetteronline-d.openx.net/w/1.0/jstag?nc=6718395-wetteronline" type="text/javascript">
#                </script>
#                <script src="//www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#                </script>
#                <script src="https://st.wetteronline.de/wodas/static/wodasHeader_async.js" type="text/javascript">
#                </script>
#                <script src="https://st.wetteronline.de/wodas/static/wodasHeaderDfpContent_async.js" type="text/javascript">
#                </script>
#                <link href="https://cnt.wetteronline.de/cgi-bin/ivw/CP/cnt.css?end_head" media="screen" rel="stylesheet" type="text/css"/>
#                <script async="" src="https://www.tisoomi-services.com/js/services.js?id=S0tOsdPqzt" type="text/javascript">
#                </script>
#                <script src="https://script.ioam.de/iam.js" type="text/javascript">
#                </script>
#               </link>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class=" free ">
#   <div id="fb-root">
#   </div>
#   <!-- ((ACTIVATE_DEBUG_TREE)) -->
#   <script src="https://st.wetteronline.de/dr/1.0.800/js/tooltip.js" type="text/javascript">
#   </script>
#   <a id="owner">
#    WetterOnline ( http://www.wetteronline.de )
#   </a>
#   <div id="totalcontainer">
#    <div id="leftcontainer">
#     <!-- ((DEBUG_TREE_CONTENT)) -->
#     <!-- neu: async -->
#     <!-- Leadboard / Wallpaper -->
#     <div class="leftflow" id="topcontainer">
#      <script type="text/javascript">
#       //q5UgyIZ("Super_01");
#      </script>
#      <div class="adplace" id="woLead" style="visibility: hidden;">
#       <div id="div-gpt-ad-1353667016621-0" style="width:auto; height: auto;">
#        <script class="adscript" type="text/javascript">
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1353667016621-0'); if(lazyLoading) googletag.pubads().refresh([leadSlot]); });
#        </script>
#       </div>
#      </div>
#      <span class="AfuerAB" id="r?3f73-hhf84d24.587.7374644d.f2e537dce4..e" style="display:none;visibility:hidden;">
#       yqNgcf
#      </span>
#      <span class="q5UgyIZ_end">
#      </span>
#     </div>
#     <!-- Content -->
#     <div id="contentcontainer">
#      <div id="header">
#       <a href="/" id="top">
#        <img alt="WetterOnline" height="55" id="logo" src="https://st.wetteronline.de/dr/1.0.800/images/logo/logo_wetteronline_250x55.png" title="WetterOnline" width="250"/>
#       </a>
#       <div id="searchbox">
#        <div id="geo-navigation-box-menu">
#        </div>
#        <form action="/" id="searchform">
#         <fieldset id="searchstring-wrapper">
#          <input accesskey="s" autocomplete="off" id="searchstring" maxlength="50" name="searchstring" tabindex="1" type="text" value=""/>
#         </fieldset>
#         <input id="searchpcid" name="searchpcid" type="hidden" value="pc_city_weather"/>
#         <input class="searchpid" name="searchpid" type="hidden" value="p_city_weather"/>
#         <input name="pid" type="hidden" value="p_search"/>
#         <input id="searchbutton" tabindex="3" type="submit" value="Wetter für Ort"/>
#        </form>
#        <div id="searchresult">
#        </div>
#        <div class="ashidden" id="autosuggestions">
#        </div>
#       </div>
#       <div id="favorites">
#       </div>
#       <div id="memberarea_wrapper">
#        <div id="memberarea">
#         <a href="/mitgliedschaft" id="membersubscription" title="Alle Infos zur WetterOnline Mitgliedschaft">
#          <span class="nobr">
#           Erfahren Sie mehr über die
#          </span>
#          <br/>
#          <span>
#           WetterOnline Mitgliedschaft
#          </span>
#         </a>
#         <a href="/login" id="memberlogin" title="Login zur WetterOnline Mitgliedschaft">
#          Login
#         </a>
#        </div>
#       </div>
#       <div id="content-navigation-wrapper">
#        <div id="content-navigation">
#         <ul class="vertical">
#          <li class="homecat mylocations ">
#           <a data-name="Home" href="/">
#            Home
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Moskau" href="/wetter/moskau">
#              Moskau
#             </a>
#            </li>
#            <li class="addloc">
#             <a data-name="Bearbeiten" href="/meine-orte" title="Meine Orte">
#              Bearbeiten
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/wetter/moskau">
#            Vorhersagen
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Moskau" href="/wetter/moskau">
#              Moskau
#             </a>
#            </li>
#            <li class="continents">
#             <a data-name="Meine Orte" href="/meine-orte">
#              Meine Orte
#             </a>
#            </li>
#            <li>
#             <a data-name="Wetterbericht" href="/wetterbericht">
#              Wetterbericht
#             </a>
#            </li>
#            <li>
#             <a data-name="14-Tage-Wetter" href="/14-tage-wetter">
#              14-Tage-Wetter
#             </a>
#            </li>
#            <li>
#             <a data-name="Wochenende" href="/wetter-wochenende">
#              Wochenende
#             </a>
#            </li>
#            <li>
#             <a data-name="Farbkarten" href="/vorhersagekarten?gid=27612">
#              Farbkarten
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li id="contentnavi_RR">
#           <a href="/regenradar/russland?gid=27612&amp;homemark=true">
#            RegenRadar
#           </a>
#           <ul class="nomouseover ">
#            <li class="contentnavi_smallScreen_RR ">
#             <a data-name="kompakt" href="/regenradar/russland?gid=27612&amp;homemark=true">
#              kompakt
#             </a>
#            </li>
#            <li class="contentnavi_fullScreen_RR">
#             <a data-name="interaktiv" href="/wetterradar?view=rain&amp;wrx=55.7500,37.6167&amp;wrg=27612&amp;wry=55.7500,37.6167&amp;wrh=true&amp;wrextent=global&amp;wrm=G0360">
#              interaktiv
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li id="contentnavi_WR">
#           <a data-name="WetterRadar" href="/wetterradar?wrx=55.7500,37.6167&amp;wrg=27612&amp;wry=55.7500,37.6167&amp;wrh=true&amp;wrextent=global&amp;wrm=G0360">
#            WetterRadar
#           </a>
#           <ul class="nomouseover ">
#            <li class="contentnavi_smallScreen_WR ">
#             <a data-name="kompakt" href="/wetterradar-aktuell/russland?gid=27612&amp;homemark=true">
#              kompakt
#             </a>
#            </li>
#            <li class="contentnavi_fullScreen_WR">
#             <a data-name="interaktiv" href="/wetterradar?wrx=55.7500,37.6167&amp;wrg=27612&amp;wry=55.7500,37.6167&amp;wrh=true&amp;wrextent=global&amp;wrm=G0360">
#              interaktiv
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="contentnavi_severeweather ">
#           <a href="/unwetter?homemark=true">
#            Unwetter
#           </a>
#           <ul class="nomouseover ">
#            <li class="contentnavi_severeweather ">
#             <a data-name="Deutschland" href="/unwetter?homemark=true">
#              Deutschland
#             </a>
#            </li>
#            <li class="contentnavi_severeweather ">
#             <a data-name="Europa" href="/unwetter/europa?homemark=true">
#              Europa
#             </a>
#            </li>
#            <li>
#             <a data-name="Rückblick" href="/extremwetter">
#              Rückblick
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/wetterticker">
#            WetterTicker
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Alle Meldungen" href="/wetterticker">
#              Alle Meldungen
#             </a>
#            </li>
#            <li>
#             <a data-name="Top-Themen" href="/themen">
#              Top-Themen
#             </a>
#            </li>
#            <li>
#             <a data-name="Fotostrecken" href="/fotostrecken">
#              Fotostrecken
#             </a>
#            </li>
#            <li>
#             <a data-name="Videos" href="/wetter-videos">
#              Videos
#             </a>
#            </li>
#            <li>
#             <a data-name="Wetterrückblick" href="/wetterrueckblick">
#              Wetterrückblick
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/aktuelles-wetter?gid=27612">
#            Wetterdaten
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Aktuell" href="/aktuelles-wetter?gid=27612">
#              Aktuell
#             </a>
#            </li>
#            <li>
#             <a data-name="Rückblick" href="/rueckblick?gid=27612">
#              Rückblick
#             </a>
#            </li>
#            <li>
#             <a data-name="Schneehöhen" href="/schnee?gid=27612">
#              Schneehöhen
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/profi-wetter?gid=27612">
#            Profi
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="ProfiKarten" href="/profiwetter/europa">
#              ProfiKarten
#             </a>
#            </li>
#            <li class="neweyecatcher ">
#             <a data-name="ProfiRadar" href="/profiradar">
#              ProfiRadar
#             </a>
#            </li>
#            <li>
#             <a data-name="Satbilder" href="/satellitenbilder?gid=27612">
#              Satbilder
#             </a>
#            </li>
#            <li>
#             <a data-name="Segelwetter" href="/segel?gid=27612">
#              Segelwetter
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/pollenvorhersage">
#            Gesundheit
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Biowetter" href="/biowetterberichte">
#              Biowetter
#             </a>
#            </li>
#            <li>
#             <a data-name="UV-Index" href="/wetter/moskau?mc=mc_health&amp;prefpar=sun">
#              UV-Index
#             </a>
#            </li>
#            <li>
#             <a class="external" data-name="VitalWetter" href="https://twitter.com/vitalwetter">
#              VitalWetter
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="activeCat ">
#           <a href="/reisen?gid=27612">
#            Reisen
#           </a>
#           <ul class="nomouseover ">
#           </ul>
#          </li>
#          <li class="last">
#           <a data-name="..." href="/apps">
#            ...
#           </a>
#           <ul class="nomouseover ">
#            <li>
#             <a data-name="Apps" href="/apps">
#              Apps
#             </a>
#            </li>
#            <li>
#             <a data-name="Alexa Skill" href="/alexa-skill">
#              Alexa Skill
#             </a>
#            </li>
#            <li>
#             <a data-name="Mitgliedschaft" href="/mitgliedschaft">
#              Mitgliedschaft
#             </a>
#            </li>
#            <li>
#             <a data-name="Social Newsroom" href="/socialnewsroom">
#              Social Newsroom
#             </a>
#            </li>
#            <li>
#             <a data-name="Homepagewetter" href="/homepagewetter/moskau">
#              Homepagewetter
#             </a>
#            </li>
#            <li>
#             <a href="/weather-api">
#              Weather-API
#             </a>
#            </li>
#            <li>
#             <a data-name="Lexikon" href="/wetterlexikon">
#              Lexikon
#             </a>
#            </li>
#            <li>
#             <a class="external" href="//wo.wetteronline.de/unternehmen/karriere" title="Karriere">
#              Karriere
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#         <ul class=" " id="fixedsubnavi">
#          <li>
#           <a data-name="Fernweh" href="/reiseziele?gid=27612">
#            Fernweh
#           </a>
#          </li>
#          <li>
#           <a data-name="Webcams" href="/wettercams?gid=27612">
#            Webcams
#           </a>
#          </li>
#          <li>
#           <a data-name="Ski &amp; Rodel" href="/schnee?gid=27612&amp;mc=mc_travel">
#            Ski &amp; Rodel
#           </a>
#          </li>
#          <li>
#           <a data-name="Wassertemperatur" href="/wassertemperaturen?gid=27612">
#            Wassertemperatur
#           </a>
#          </li>
#          <li>
#           <a data-name="Reiseplaner" href="/reiseplaner/moskau">
#            Reiseplaner
#           </a>
#          </li>
#          <li>
#           <a data-name="Klima" href="/klima?gid=27612">
#            Klima
#           </a>
#          </li>
#         </ul>
#         <ul id="socialmedia">
#          <li>
#           <a class="facebook" data-counterurl="https://cnt.wetteronline.de/cgi-bin/goto" data-tt="Diese Seite bei Facebook teilen" href="https://www.facebook.com/sharer/sharer.php?u=http://www.wetteronline.de/?pcid=pc_rueckblick_climate%26amp;gid=27612%26amp;pid=p_rueckblick_climatecalculator%26amp;sid=Default%26amp;iid=27612" rel="nofollow" title="Diese Seite bei Facebook teilen">
#            Diese Seite bei Facebook teilen
#           </a>
#          </li>
#          <li>
#           <a class="twitter" data-counterurl="https://cnt.wetteronline.de/cgi-bin/goto" data-tt="Diese Seite bei Twitter teilen" href="https://twitter.com/intent/tweet?url=http://www.wetteronline.de/?pcid=pc_rueckblick_climate%26amp;gid=27612%26amp;pid=p_rueckblick_climatecalculator%26amp;sid=Default%26amp;iid=27612&amp;text=Klima in der Region Moskau - Klimarechner - WetterOnline" rel="nofollow" title="Diese Seite bei Twitter teilen">
#            Diese Seite bei Twitter teilen
#           </a>
#          </li>
#          <li>
#           <a class="bookmark" data-tt="Link zu dieser Seite / Seite empfehlen" href="http://www.wetteronline.de/?pcid=pc_rueckblick_climate&amp;gid=27612&amp;pid=p_rueckblick_climatecalculator&amp;sid=Default&amp;iid=27612">
#            Link zu dieser Seite
#           </a>
#          </li>
#          <li class="top-gap">
#           <a class="newsletter" data-counterurl="https://cnt.wetteronline.de/cgi-bin/goto" data-tt="WetterOnline Newsletter" href="/newsletter?source=socialbar" title="WetterOnline Newsletter abonnieren">
#            Newsletter
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <!-- Billboard -->
#      <div class="billboard" id="woBillboard" style="display: none;">
#       <!-- WO_Content_Billboard_970x90 -->
#       <div id="div-gpt-ad-1380112768904-0" style="max-width:997px;height:auto;">
#        <script type="text/javascript">
#         if ( setBill == true ) googletag.cmd.push(function() { googletag.display('div-gpt-ad-1380112768904-0'); if(lazyLoading) googletag.pubads().refresh([billSlot]); });
#        </script>
#       </div>
#      </div>
#      <div id="content">
#       <div id="maincontent">
#        <div id="subheader">
#         <div id="universal-symbols">
#          <span class="uploaderlink" title="Senden Sie uns Ihre Bilder/Videos">
#           <a class="uploadlink headline woinfo" href="/uploader" id="show_upload">
#            Senden Sie uns Ihre Bilder/Videos
#           </a>
#          </span>
#          <span class="printpage" title="Seite drucken">
#          </span>
#          <span class="reloadpage" title="Seite neu laden">
#          </span>
#         </div>
#        </div>
#        <div class="p_rueckblick_climatecalculator Default" id="pc">
#         <h1 id="content_headline">
#          <span>
#           Klima in der Region Moskau
#          </span>
#         </h1>
#         <div id="switch_tab">
#          <ul>
#           <li>
#            <a href="/klima-temperatur/moskau">
#             Diagramme
#            </a>
#           </li>
#           <li>
#            <a href="/reiseplaner/moskau">
#             Reiseplaner
#            </a>
#           </li>
#           <li>
#            <a href="/klimawandel-temperatur/moskau">
#             Klimaverlauf
#            </a>
#           </li>
#           <li class="activeswitch">
#            <a href="/klimarechner/moskau">
#             Klimarechner
#            </a>
#           </li>
#           <li>
#            <a href="/klima-suche?gid=27612">
#             Wunschklima
#            </a>
#           </li>
#           <li>
#            <a href="/klima-karte/europa?gid=27612">
#             Farbkarten
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div id="product">
#          <script type="text/javascript">
#           WO.c.pid.cur = 'p_rueckblick_climatecalculator';
#  WO.c.sid.cur = 'Default';
#  WO.c.iid.cur = '27612';
#  WO.date.month = '08';
#          </script>
#          <script src="https://st.wetteronline.de/dr/1.0.800/js/p_rueckblick.js" type="text/javascript">
#          </script>
#          <script src="https://st.wetteronline.de/dr/1.0.800/js/pc_rueckblick_climate.js" type="text/javascript">
#          </script>
#          <div class="p_rueckblick_climatecalculator" id="product_display">
#           <form action="/" id="para_choice">
#            <input name="pcid" type="hidden" value="pc_rueckblick_climate"/>
#            <input name="gid" type="hidden" value="27612"/>
#            <input name="iid" type="hidden" value="27612"/>
#            <input name="pid" type="hidden" value="p_rueckblick_climatecalculator"/>
#            <input name="sid" type="hidden" value="Default"/>
#            <fieldset class="para_ana_select">
#             <select id="var" name="var">
#              <option value="FD">
#               Frosttage
#              </option>
#              <option value="FFkmh">
#               Windstärke
#              </option>
#              <option value="FXD">
#               Tage mit Böen &gt; 45 km/h
#              </option>
#              <option value="ND">
#               Niederschlagstage
#              </option>
#              <option value="NS">
#               Niederschlagsmenge
#              </option>
#              <option value="TN">
#               Nächtliche Tiefsttemperatur
#              </option>
#              <option selected="selected" value="TX">
#               Tageshöchsttemperatur
#              </option>
#             </select>
#             <label for="analysis">
#              Analyseart
#             </label>
#             <select id="analysis" name="analysis">
#              <option value="annual">
#               Jahr
#              </option>
#              <option selected="selected" value="monthly">
#               Monat
#              </option>
#             </select>
#            </fieldset>
#            <fieldset id="month_select">
#             <select id="month" name="month" size="1">
#              <option value="01">
#               Januar
#              </option>
#              <option value="02">
#               Februar
#              </option>
#              <option value="03">
#               März
#              </option>
#              <option value="04">
#               April
#              </option>
#              <option value="05">
#               Mai
#              </option>
#              <option value="06">
#               Juni
#              </option>
#              <option value="07">
#               Juli
#              </option>
#              <option value="08">
#               August
#              </option>
#              <option value="09">
#               September
#              </option>
#              <option value="10">
#               Oktober
#              </option>
#              <option value="11">
#               November
#              </option>
#              <option value="12">
#               Dezember
#              </option>
#             </select>
#            </fieldset>
#            <fieldset class="year_select">
#             <select id="startyear" name="startyear">
#              <option value="2017">
#               2017
#              </option>
#              <option value="2016">
#               2016
#              </option>
#              <option value="2015">
#               2015
#              </option>
#              <option value="2014">
#               2014
#              </option>
#              <option value="2013">
#               2013
#              </option>
#              <option value="2012">
#               2012
#              </option>
#              <option value="2011">
#               2011
#              </option>
#              <option value="2010">
#               2010
#              </option>
#              <option value="2009">
#               2009
#              </option>
#              <option value="2008">
#               2008
#              </option>
#              <option value="2007">
#               2007
#              </option>
#              <option value="2006">
#               2006
#              </option>
#              <option value="2005">
#               2005
#              </option>
#              <option value="2004">
#               2004
#              </option>
#              <option value="2003">
#               2003
#              </option>
#              <option value="2002">
#               2002
#              </option>
#              <option value="2001">
#               2001
#              </option>
#              <option value="2000">
#               2000
#              </option>
#              <option value="1999">
#               1999
#              </option>
#              <option value="1998">
#               1998
#              </option>
#              <option value="1997">
#               1997
#              </option>
#              <option value="1996">
#               1996
#              </option>
#              <option value="1995">
#               1995
#              </option>
#              <option value="1994">
#               1994
#              </option>
#              <option value="1993">
#               1993
#              </option>
#              <option value="1992">
#               1992
#              </option>
#              <option value="1991">
#               1991
#              </option>
#              <option selected="selected" value="1990">
#               1990
#              </option>
#             </select>
#             <label for="startyear">
#              bis
#             </label>
#             <select id="endyear" name="endyear">
#              <option selected="selected" value="2017">
#               2017
#              </option>
#              <option value="2016">
#               2016
#              </option>
#              <option value="2015">
#               2015
#              </option>
#              <option value="2014">
#               2014
#              </option>
#              <option value="2013">
#               2013
#              </option>
#              <option value="2012">
#               2012
#              </option>
#              <option value="2011">
#               2011
#              </option>
#              <option value="2010">
#               2010
#              </option>
#              <option value="2009">
#               2009
#              </option>
#              <option value="2008">
#               2008
#              </option>
#              <option value="2007">
#               2007
#              </option>
#              <option value="2006">
#               2006
#              </option>
#              <option value="2005">
#               2005
#              </option>
#              <option value="2004">
#               2004
#              </option>
#              <option value="2003">
#               2003
#              </option>
#              <option value="2002">
#               2002
#              </option>
#              <option value="2001">
#               2001
#              </option>
#              <option value="2000">
#               2000
#              </option>
#              <option value="1999">
#               1999
#              </option>
#              <option value="1998">
#               1998
#              </option>
#              <option value="1997">
#               1997
#              </option>
#              <option value="1996">
#               1996
#              </option>
#              <option value="1995">
#               1995
#              </option>
#              <option value="1994">
#               1994
#              </option>
#              <option value="1993">
#               1993
#              </option>
#              <option value="1992">
#               1992
#              </option>
#              <option value="1991">
#               1991
#              </option>
#              <option value="1990">
#               1990
#              </option>
#             </select>
#             <input name="iid" type="hidden" value="27612"/>
#             <input class="submit" type="submit" value=""/>
#            </fieldset>
#           </form>
#           <div class="table_wrapper">
#            <table id="climatecalculator_result">
#             <thead>
#              <tr class="headline">
#               <th colspan="2">
#                Monatsanalyse
#               </th>
#              </tr>
#              <tr class="headline">
#               <th colspan="2">
#                Tageshöchsttemperatur August
#                <br/>
#                Wetterstation Moskau
#               </th>
#              </tr>
#              <tr class="mean">
#               <th>
#                Mittel 1990 - 2017
#               </th>
#               <th>
#                22.3 °C
#               </th>
#              </tr>
#              <tr class="divide">
#               <th colspan="2">
#               </th>
#              </tr>
#              <tr class="detailhead">
#               <th>
#                Jahr
#               </th>
#               <th>
#               </th>
#              </tr>
#             </thead>
#             <tbody>
#              <tr>
#               <td>
#                2017
#               </td>
#               <td>
#                25.4 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2016
#               </td>
#               <td>
#                24.7 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2015
#               </td>
#               <td>
#                22.8 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2014
#               </td>
#               <td>
#                24.9 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2013
#               </td>
#               <td>
#                23.8 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2012
#               </td>
#               <td>
#                22.4 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2011
#               </td>
#               <td>
#                24.1 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2010
#               </td>
#               <td>
#                27.3 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2009
#               </td>
#               <td>
#                20.2 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2008
#               </td>
#               <td>
#                21.7 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2007
#               </td>
#               <td>
#                25.7 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2006
#               </td>
#               <td>
#                21.7 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2005
#               </td>
#               <td>
#                23.1 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2004
#               </td>
#               <td>
#                23.6 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2003
#               </td>
#               <td>
#                21.2 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2002
#               </td>
#               <td>
#                22.7 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                2001
#               </td>
#               <td>
#                21.6 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                2000
#               </td>
#               <td>
#                21.3 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1999
#               </td>
#               <td>
#                21.2 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                1998
#               </td>
#               <td>
#                19.3 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1997
#               </td>
#               <td>
#                22.1 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                1996
#               </td>
#               <td>
#                - °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1995
#               </td>
#               <td>
#                21.1 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                1994
#               </td>
#               <td>
#                19.6 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1993
#               </td>
#               <td>
#                19.2 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                1992
#               </td>
#               <td>
#                22.4 °C
#               </td>
#              </tr>
#              <tr>
#               <td>
#                1991
#               </td>
#               <td>
#                19.9 °C
#               </td>
#              </tr>
#              <tr class="odd">
#               <td>
#                1990
#               </td>
#               <td>
#                19.8 °C
#               </td>
#              </tr>
#             </tbody>
#            </table>
#           </div>
#           <div id="globalnavi-wrapper">
#            <form id="furthersearchform">
#             <label for="furthersearchstring">
#              Klimaanalyse für:
#             </label>
#             <input autocomplete="off" id="furthersearchstring" maxlength="50" name="searchstring" type="text" value="Mein Ort"/>
#             <input class="searchpcid" name="searchpcid" type="hidden" value="pc_rueckblick_climate"/>
#             <input class="searchpid" name="searchpid" type="hidden" value="p_rueckblick_climatecalculator"/>
#             <input class="searchsid" name="searchsid" type="hidden" value="Default"/>
#             <input class="additional" name="month" type="hidden" value="08"/>
#             <input class="additional" name="startyear" type="hidden" value="1990"/>
#             <input class="additional" name="endyear" type="hidden" value="2017"/>
#             <input class="additional" name="analysis" type="hidden" value="monthly"/>
#             <input class="additional" name="var" type="hidden" value="TX"/>
#             <input name="pid" type="hidden" value="p_search"/>
#             <input class="searchsubmit" type="submit" value="Suchen"/>
#             <div class="ashidden" id="furtherautosuggestions">
#             </div>
#            </form>
#           </div>
#          </div>
#         </div>
#         <div id="instance_navigation">
#         </div>
#        </div>
#        <style>
#         div.JocODpJZXc {float:left;}
#        </style>
#        <div class="JocODpJZXc">
#         <script type="text/javascript">
#          //q5UgyIZ("Medium_02")
#         </script>
#         <div class="adplace" id="woDoRect">
#          <!-- /6718395/WO_Content_CSI_www2_620x300 -->
#          <div id="div-gpt-ad-1447758109299-0" style="height: auto; width:620px;">
#           <script type="text/javascript">
#            if(document.getElementById('woDoRectPro') == null){
#         googletag.cmd.push(function() { googletag.display('div-gpt-ad-1447758109299-0'); if(lazyLoading) googletag.pubads().refresh([dRectSlot]); });
#       }else{
#         document.getElementById("woDoRect").style.display = 'none';
#       }
#           </script>
#          </div>
#         </div>
#         <span class="q5UgyIZ_end">
#         </span>
#         <script type="text/javascript">
#          //q5UgyIZ("Medium_03")
#         </script>
#         <span class="AfuerAB" id="r?hefe9ecdd2e.9867975hg..7c75g4e.9c3c4c7h4" style="display:none;visibility:hidden;">
#         </span>
#         <span class="q5UgyIZ_end">
#         </span>
#        </div>
#        <div class="linewrapper pc_rueckblick_climate" id="multimedia_teaser">
#         <script src="https://st.wetteronline.de/dr/1.0.800/js/wotexte_multimedia_rotation.js" type="text/javascript">
#         </script>
#         <div class="multimedia_box teaser_block" id="gallery_rotation">
#         </div>
#         <script>
#          (function() {
# 		new Rotation({
#         status: "gallery",
#         media: [
#         	{
#     title:      "Der Durchzug einer Kaltfront",
#     subtitle:   "WetterWissen",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170818_kf_300x169_9066755ba67050d38cbb6037f57727f1.jpg"].join('&'),
#     alt:        "WetterWissen",
#     link:       "/fotostrecken/2017-08-18-kf?part=single",
#     weight:     1
# },
# {
#     title:      "Unwetter hinterlassen Schäden",
#     subtitle:   "Heftige Gewitter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_uw_300x169_188ac2de6bdc66ec565fb53ea888b214.jpg"].join('&'),
#     alt:        "Heftige Gewitter",
#     link:       "/fotostrecken/2017-08-19-uw?part=single",
#     weight:     1
# },
# {
#     title:      "Extreme Sturmschäden bei Fürth",
#     subtitle:   "Unwetter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_fu_300x169_7e1e26f25f88c7c9a79531a000d84682.jpg"].join('&'),
#     alt:        "Unwetter",
#     link:       "/fotostrecken/2017-08-19-fu?part=single",
#     weight:     1
# },
# {
#     title:      "Extreme Sturmschäden bei Fürth",
#     subtitle:   "Unwetter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_fu_300x169_6831d3488cba6ffe70fc42078516da00.jpg"].join('&'),
#     alt:        "Unwetter",
#     link:       "/fotostrecken/2017-08-19-fu?part=single",
#     weight:     1
# },
# {
#     title:      "Extreme Sturmschäden bei Fürth",
#     subtitle:   "Unwetter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_fu_300x169_42a107f94e0aad19665af09783ab873c.jpg"].join('&'),
#     alt:        "Unwetter",
#     link:       "/fotostrecken/2017-08-19-fu?part=single",
#     weight:     1
# },
# {
#     title:      "USA im Sonnenfinsternis-Fieber",
#     subtitle:   "Astronomie",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170821_sf_300x169_7c47f88d76fe253083be36b94782d50d.jpg"].join('&'),
#     alt:        "Astronomie",
#     link:       "/fotostrecken/2017-08-21-sf?part=single",
#     weight:     2
# },
# {
#     title:      "USA im Sonnenfinsternis-Fieber",
#     subtitle:   "Astronomie",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170821_sf_300x169_0154ec5464e64c8503248829677113e3.jpg"].join('&'),
#     alt:        "Astronomie",
#     link:       "/fotostrecken/2017-08-21-sf?part=single",
#     weight:     2
# },
# {
#     title:      "USA im Sonnenfinsternis-Fieber",
#     subtitle:   "Astronomie",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170821_sf_300x169_f5e25014df911a67a34af707aa561068.jpg"].join('&'),
#     alt:        "Astronomie",
#     link:       "/fotostrecken/2017-08-21-sf?part=single",
#     weight:     2
# },
# {
#     title:      "USA im Sonnenfinsternis-Fieber",
#     subtitle:   "Astronomie",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170821_sf_300x169_1e20a360c75e82572432efb3b68367af.jpg"].join('&'),
#     alt:        "Astronomie",
#     link:       "/fotostrecken/2017-08-21-sf?part=single",
#     weight:     2
# }
# 	],
#         settings: {
#                 height: 169,
#                 width: 300,
# 		overlay: "https://st.wetteronline.de/dr/1.0.800/images/overlay/overlay_gallery_288x162.png"
#         }
# }, "gallery_rotation");
# 	})();
#         </script>
#         <div class="multimedia_box teaser_block" id="video_rotation">
#         </div>
#         <script>
#          (function() {
# 		new Rotation({
#         status: "video",
#         media: [
#         	{
#     title:      "USA: Vor der Sonnenfinsternis",
#     subtitle:   "WetterReporter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170816_as_300x169_96e72239b0ca970750a6412b4d9d0b14.jpg"].join('&'),
#     alt:        "WetterReporter",
#     link:       "/wetter-videos/2017-08-16-as?sort=date",
#     weight:     1
# },
# {
#     title:      "Wenn Wolken eine Kappe bekommen",
#     subtitle:   "Wolkenzeitraffer",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170817_pi_300x169_216104ba61e7fe57fcf8e50a264af625.jpg"].join('&'),
#     alt:        "Wolkenzeitraffer",
#     link:       "/wetter-videos/2017-08-17-pi?sort=date",
#     weight:     1
# },
# {
#     title:      "Schwere Unwetter im Südosten",
#     subtitle:   "Schäden durch Sturmböen",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_uw_300x169_347774b957c4f8b372615f8e61f21392.jpg"].join('&'),
#     alt:        "Schäden durch Sturmböen",
#     link:       "/wetter-videos/2017-08-19-uw?sort=date",
#     weight:     1
# },
# {
#     title:      "Gewitterfallböen wüten bei Fürth",
#     subtitle:   "Unwetterschäden",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_fu_300x169_03f86f2e57c42834feb00182c5a76c43.jpg"].join('&'),
#     alt:        "Unwetterschäden",
#     link:       "/wetter-videos/2017-08-19-fu?sort=date",
#     weight:     1
# },
# {
#     title:      "Schäden durch Hagelunwetter",
#     subtitle:   "Unwetter",
#     image:      ["/?pid=p_wotexte_multimedia", "ireq=true", "src=wotexte/vermarktung/snippets/multimediaRotation/image_20170819_mk_300x169_3e4319ff8e4cbf41f118dc379e61b23d.jpg"].join('&'),
#     alt:        "Unwetter",
#     link:       "/wetter-videos/2017-08-19-mk?sort=date",
#     weight:     1
# },
# {
#     title:      "Ist der Sommer 2017 vorbei?",
#     subtitle:   "Hoffnungsschimmer für Wärmefans",
# ...
#        </span>
#        Orte in der Nähe
#       </h3>
#       <hr/>
#       <ul>
#        <li>
#         <a href="/wetter/cheremushki-russland" title="Wetter Cherëmushki">
#          Cherëmushki
#         </a>
#        </li>
#        <li>
#         <a href="/wetter/bibirevo" title="Wetter Bibirevo">
#          Bibirevo
#         </a>
#        </li>
#        <li>
#         <a href="/wetter/vostochnoe-degunino" title="Wetter Vostochnoe Degunino">
#          Vostochnoe Degunino
#         </a>
#        </li>
#        <li>
#         <a href="/wetter/reutow" title="Wetter Reutow">
#          Reutow
#         </a>
#        </li>
#        <li>
#         <a href="/wetter/zarech-ye" title="Wetter Zarech'ye">
#          Zarech'ye
#         </a>
#        </li>
#        <li>
#         <a href="/wetter/nemchinovka" title="Wetter Nemchinovka">
#          Nemchinovka
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="clearfix">
#     </div>
#     <div id="static-navigation">
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    WO.requestTime = new Date();
#     try {
#      window.fireEvent('woready');
#     }
#     catch(e) {
#      log(e)
#     }
#
#     dataLayer.push({'IVW':'pc_rueckblick_climate_p_rueckblick_climatecalculator_Default'});
#     dataLayer.push({'gid':'27612'});
#     dataLayer.push({'level':'free'});
#     dataLayer.push({'member':'false'});
#     dataLayer.push({'pid':'p_rueckblick_climatecalculator'});
#     dataLayer.push({'acceptsCookies':WO.acceptsCookies?'true':'false'});
#
#     var newImg = document.createElement('img');
#     newImg.src = "https://cnt.wetteronline.de/cgi-bin/ivw/CP/pagecoun?IVW=pc_rueckblick_climate_p_rueckblick_climatecalculator_Default&gid=27612&vtyp=www&level=free&member=false&LANG=de&d=" + WO.requestTime.getTime();
#     newImg.width = 1;
#     newImg.height = 1;
#     newImg.setAttribute("id", "pagecoun");
#     document.getElementsByTagName("body")[0].appendChild(newImg);
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-TCV7C3');
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://cnt.wetteronline.de/cgi-bin/ivw/CP/pagecoun?IVW=pc_rueckblick_climate_p_rueckblick_climatecalculator_Default&amp;gid=27612&amp;vtyp=www&amp;level=free&amp;member=false&amp;LANG=de" width="1"/>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TCV7C3" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div id="woFooter">
#    <script src="https://st.wetteronline.de/wodas/static/wodasFooter.js" type="text/javascript">
#    </script>
#    <script src="//media.oadts.com/www/delivery/video.php?dt=inline&amp;mw=400&amp;sm=1&amp;tm=1&amp;vp=120" type="text/javascript">
#    </script>
#    <script src="https://st.wetteronline.de/wodas/static/footerCalls.js" type="text/javascript">
#    </script>
#   </div>
#   <div class="leftflow">
#    <!-- layer not found -->
#   </div>
#   <script type="text/javascript">
#    var sc,CriteoAdblockPlusRect=function(){sc=!0;var e=292403,t="#CLICK_URL_UNESC#";!function(e,t,n,o,i,r){var c=t.getElementsByTagName(n)[0],a=t.createElement(n),s="&loc="+encodeURIComponent(e.location),l=t.referrer?"&referer="+encodeURIComponent(t.referrer):"",d="http"==r.substring(0,4)?"&ct0="+encodeURIComponent(r):"",p="&cb="+Math.floor(99999999999*Math.random());a.async="true",a.src=(("https:"==location.protocol?"https:":"http:")+"//cas.criteo.com/delivery/ajs.php?zoneid="+i+"&containerid="+o+d+s+l+p).substring(0,2e3),c.parentNode.insertBefore(a,c);var h=3,w=function(){null!=$("woMediumRectangle")?$("woMediumRectangle").remove():h>0&&(--h,setTimeout(w,1e3))};setTimeout(w,1e3),$("woRect").setStyle("display","block")}(window,document,"script","woRect",e,t)},CriteoAdblockPlusSky=function(){sc=!0;var e=new Element("div",{id:"right2container","class":"leftflow"});e.inject($("rightcontainer").getParent()),e.setStyle("top","-15px"),e.setStyle("width",$("rightcontainer").getStyle("width")),e.setStyle("left",$("rightcontainer").getStyle("left")),e.setStyle("height",$("rightcontainer").getStyle("height")),e.setStyle("position",$("rightcontainer").getStyle("position")),e.setStyle("z-index",$("rightcontainer").getStyle("z-index")),e.setStyle("padding-top","15px");var t=320142,n="#CLICK_URL_UNESC#";!function(e,t,n,o,i,r){var c=t.getElementsByTagName(n)[0],a=t.createElement(n),s="&loc="+encodeURIComponent(e.location),l=t.referrer?"&referer="+encodeURIComponent(t.referrer):"",d="http"==r.substring(0,4)?"&ct0="+encodeURIComponent(r):"",p="&cb="+Math.floor(99999999999*Math.random());a.async="true",a.src=(("https:"==location.protocol?"https:":"http:")+"//cas.criteo.com/delivery/ajs.php?zoneid="+i+"&containerid="+o+d+s+l+p).substring(0,2e3),c.parentNode.insertBefore(a,c),$("right2container").setStyle("background",'rgba(0, 0, 0, 0) url("https://st.wetteronline.de/wodas/images/anzeige_40x12.gif") no-repeat scroll right 0px');var h=3,w=function(){var e="p_home"==WO.c.pid.cur?"div-gpt-ad-1359624003739-2":"div-gpt-ad-1353667016621-2";null!=$(e)?$(e).remove():h>0&&(--h,setTimeout(w,1e3))};setTimeout(w,1e3)}(window,document,"script","right2container",t,n)},CriteoAdblockPlusLead=function(){var e=new Element("div",{id:"top2container","class":"leftflow"});e.inject($("topcontainer").getParent()),e.setStyle("top",$("topcontainer").getStyle("top")),e.setStyle("width",$("topcontainer").getStyle("width")),e.setStyle("left",$("topcontainer").getStyle("left")),e.setStyle("height",$("topcontainer").getStyle("height")),e.setStyle("position",$("topcontainer").getStyle("position")),e.setStyle("z-index",$("topcontainer").getStyle("z-index")),e.setStyle("text-align","right");var t=320143,n="#CLICK_URL_UNESC#";!function(e,t,n,o,i,r){var c=t.getElementsByTagName(n)[0],a=t.createElement(n),s="&loc="+encodeURIComponent(e.location),l=t.referrer?"&referer="+encodeURIComponent(t.referrer):"",d="http"==r.substring(0,4)?"&ct0="+encodeURIComponent(r):"",p="&cb="+Math.floor(99999999999*Math.random());a.async="true",a.src=(("https:"==location.protocol?"https:":"http:")+"//cas.criteo.com/delivery/ajs.php?zoneid="+i+"&containerid="+o+d+s+l+p).substring(0,2e3),c.parentNode.insertBefore(a,c),$("top2container").setStyle("background",'rgba(0, 0, 0, 0) url("https://st.wetteronline.de/wodas/images/anzeige_40x12.gif") no-repeat scroll 225px 0');var h=3,w=function(){var e="p_home"==WO.c.pid.cur?"div-gpt-ad-1359624003739-0":"div-gpt-ad-1353667016621-0";null!=$(e)?$(e).remove():h>0&&(--h,setTimeout(w,1e3))};setTimeout(w,1e3)}(window,document,"script","top2container",t,n)},AdblockPlus=new function(){this.detect=function(e,t){function n(e,t){0==r||t>1e3?e(0==r&&i):setTimeout(function(){n(e,2*t)},2*t)}function o(){--r||(i=!c&&a)}var i=!1,r=2,c=!1,a=!1;if("function"==typeof t){e+="?ch=*&rn=*";var s=11*Math.random(),l=new Image;l.onload=o,l.onerror=function(){c=!0,o()},l.src=e.replace(/\*/,1).replace(/\*/,s);var d=new Image;d.onload=o,d.onerror=function(){a=!0,o()},d.src=e.replace(/\*/,2).re ...
#   </script>
#   <script type="text/javascript">
#    if('aCount' in window == false){var tCount = new Element('img', {width: 1, height: 1, alt: '', src: ['https://cnt.wetteronline.de/cgi-bin/ivw/CP/setcnt?mad_wo_tiso_pi&timestamp=',WO.starttime.getTime()].join('')}); document.body.adopt(tCount);} window.xq5UgyIZx = 'https://st'+WO.system+'.wetteronline.de/';if(localStorage.getItem('tisoomi_dataprivacy')!=null)window.chfp=0;
#   </script>
#   <script type="text/javascript">
#    !function(e,t,r){ function x(e){ var r=e.srch;e.srch=function(){ t.tsLayer=function(t){ t?e.crS("Layer"):r() },setTimeout(function(){ try{ WO.adblock.cbl.onDetectionFinished(1) }catch(e){ } },10) } }function w(e){ "use strict";var t=function(e,t){ if(e){ for(var r=t.split("/"),n=r.length-1;n>0;n--)if(["U","D","M"].indexOf(r[n])>-1){ r.splice(n,1);break }t=r.join("/") }return t };e.addPostProcessUnit(9997,function(e){ return"string"==typeof e.im?e.im=t(!0,e.im):U(e.im)&&(e.im=e.im.map(function(e){ return t(!0,e) })),e }) }function b(e){ "use strict";var t=function(e,t){ if(e&&t.length>0){ var r=t.split("/"),n=r[r.length-2],i="",a=n.indexOf("-");a>-1&&(i=n.slice(0,a+1),n=n.substr(a+1));for(var c,o="14/14/",s=o.split("/").map(Number),u=[],f=0;f<s.length-1;f++)c=s[f],c>0&&c<n.length&&(u.push(n.substr(0,c)),n=n.substr(c));u.push(n),n=u.join("/"),r[r.length-2]=i+n,t=r.join("/") }return t };e.addPostProcessUnit(9998,function(e){ if("function"==typeof e.cl){ var r=e.cl;e.cl=function(n,i,a){ var o=r.call(e,n,i,a);return o?t(!1,o):null } }else U(e.cl)&&(e.cl=e.cl.map(function(r){ return function(n,i,a){ var o=r.call(e,n,i,a);return o?t(!1,o):null } }));return"string"==typeof e.im?e.im=t(!0,e.im):U(e.im)&&(e.im=e.im.map(function(e){ return t(!0,e) })),e }) }function k(r){ "use strict";r.pID="q5UgyIZ",r.pList=["Sky_02","Super_02","Medium_01","Medium_02","Medium_03","Full_01","Full_02","Billboard","Sky_01","Super_01"],r.regexp=/q5UgyIZ\(["']([\w\s\.-]+)["']\)/i,r.arr=[],r.done=[],r.srch=function(){ var t,n=e.scripts;for(t=0;t<n.length;t+=1)r.doesContentMatch(n[t])&&r.matchInPList(n[t])&&r.matchNotDone(n[t])&&(r.collectAdTagContents(n[t]),r.createAdTag(r.regexp.exec(n[t].innerHTML)[1],n[t]),r.done.push(r.regexp.exec(n[t].innerHTML)[1]));r.done=[] },r.doesContentMatch=function(e){ return e&&r.regexp.test(e.innerHTML) },r.mFn=r.doesContentMatch,r.matchInPList=function(e){ return e&&r.pList.indexOf(r.regexp.exec(e.innerHTML)[1])>=0 },r.mEn=r.matchInPList,r.matchNotDone=function(e){ return e&&r.done.indexOf(r.regexp.exec(e.innerHTML)[1])<0 },r.mNd=r.matchNotDone,r.collectAdTagContents=function(e){ if(e){ var s,t=e.parentNode.childNodes,n=null,i=null,a=null,o=r.regexp.exec(e.innerHTML)[1];for(s=0;s<t.length;s+=1)if(n=t[s],"SCRIPT"===n.nodeName&&r.regexp.test(n.innerHTML)&&r.regexp.exec(n.innerHTML)[1]===o){ i=s;break }if(null!==i)for(s=i+1;s<t.length;s+=1)if(n=t[s],"SPAN"===n.nodeName&&n.className.indexOf(r.pID+"_end")+1){ a=s;break }if(null!==i&&null!==a)for(s=i+1;s<a;s+=1)n=t[s],Node.ELEMENT_NODE!==n.nodeType&&Node.CDATA_SECTION_NODE!==n.nodeType&&Node.COMMENT_NODE!==n.nodeType||r.arr.push(n) } },r.col=r.collectAdTagContents,r.crS=function(t){ var n,i=e.scripts;for(n=0;n<i.length;n+=1)if(r.doesContentMatch(i[n])&&r.regexp.exec(i[n].innerHTML)[1]===t){ r.collectAdTagContents(i[n]),r.createAdTag(r.regexp.exec(i[n].innerHTML)[1],i[n]);break } },r.postProcessUnitArray=[],r.addPostProcessUnit=function(e,t){ r.postProcessUnitArray.push({ priority:e,f:t }) },r.postProcessUnit=function(e,t){ r.postProcessUnitArray=r.postProcessUnitArray.sort(function(e,t){ return e.priority>t.priority?1:e.priority===t.priority?0:-1 });var n;for(n=0;n<r.postProcessUnitArray.length;n+=1)e=r.postProcessUnitArray[n].f.call(t||r,e);return e },r.createAdTag=function(s,c){ if(c){ var d,l=e.createElement("div"),p=e.createElement("div"),h=e.createElement("div");L()||(h.style.cssText="display:block !important;"),r.arr&&(d=r.arr,setTimeout(function(){ for(var e=0;e<d.length;e+=1)void 0!==d[e].style?d[e].style.setProperty("display","none"):p.appendChild(d[e]) },100)),r.arr=[];var v,m=function(){ c.parentNode.insertBefore(l,c.nextSibling),l.appendChild(h) };switch(s){ case"Sky_02":var v={ st:"TwaF4v7VVlp5",ss:"cursor:pointer; max-width:160px; max-height:600px;",sd:"max-width:300px; position:relative; ",sm:"",im:n+"image/sites/"+i+"/"+o+"/"+a+"OsNET2V98.jpg",m:1,cl:function(e,t,r){ return n+"image/sites/"+o+"/"+e+"f"+t+"/"+a+"OsNET2V9s.jpg" },extra:"",ins:"",ifr:!1,fb:!1,ifrBloc ...
#   </script>
#   <script type="text/javascript">
#    if(function(){window.MutationObserver=window.MutationObserver||window.WebKitMutationObserver||window.MozMutationObserver;var e=$("contentcontainer"),l=new MutationObserver(function(){$$("footer").length>0&&"undefined"!=typeof WO.pageIsCenterable&&1==WO.pageIsCenterable&&($$("footer").setStyle("top",String($("contentcontainer").getPosition().y+2)+"px"),$("stuff-wrapper").setStyle("margin-left",-1*($("leftcontainer").getDimensions().width-$("contentcontainer").getDimensions().width)/2)),l.disconnect()}),a={attributes:!0};l.observe(e,a)}(),WO.adblock=WO.adblock||{},WO.adblock.cbl=WO.adblock.cbl||{},WO.adblock.cbl.user={},WO.adblock.cbl.isThisACblPage=function(){try{if("www"==WO.application&&("p_wmaps_viewport"==WO.c.pid.cur||"p_radar_map"==WO.c.pid.cur))return!0}catch(e){log("Adblock CBL: ",e)}return!1},1==WO.adblock.cbl.isThisACblPage()){var newDiv=document.createElement("div");newDiv.innerHTML='<scr'+'ipt type="text/javascript"> //q5UgyIZ("Layer") </scr'+'ipt> <span class="q5UgyIZ_end"></span>',document.getElementsByTagName("body")[0].appendChild(newDiv)}WO.adblock.cbl.onDetectionFinished=function(e){try{var l=function(e){if(1!=WO.adblock.cbl.userCreated&&WO.localStorageUseable!==!1){if(WO.adblock.cbl.user.group=localStorage.getItem("cbl_user_group"),"c"!=WO.adblock.cbl.user.group&&"d"!=WO.adblock.cbl.user.group||(WO.adblock.cbl.clearData(),WO.adblock.cbl.user.group=null),null==localStorage.getItem("cbl_user_group")){if(1!=e)return;if(0==WO.adblock.cbl.isThisACblPage())return}null==WO.adblock.cbl.user.group&&(WO.adblock.cbl.user.group=Math.random()<.5?"a":"b",localStorage.setItem("cbl_user_group",WO.adblock.cbl.user.group)),WO.adblock.cbl.user.adblockStatus=localStorage.getItem("cbl_user_adblockStatus"),null==WO.adblock.cbl.user.adblockStatus&&(WO.adblock.cbl.user.adblockStatus="enabled",localStorage.setItem("cbl_user_adblockStatus",WO.adblock.cbl.user.adblockStatus)),WO.adblock.cbl.user.lastvisit=localStorage.getItem("cbl_user_lastvisit"),null==WO.adblock.cbl.user.lastvisit,WO.adblock.cbl.user.sessions=localStorage.getItem("cbl_user_sessions"),null==WO.adblock.cbl.user.sessions?(WO.adblock.cbl.user.sessions=0,localStorage.setItem("cbl_user_sessions",WO.adblock.cbl.user.sessions)):WO.adblock.cbl.user.sessions=Number(WO.adblock.cbl.user.sessions),WO.adblock.cbl.user.firstdeaktivation=localStorage.getItem("cbl_user_firstdeaktivation"),null!=WO.adblock.cbl.user.firstdeaktivation&&(WO.adblock.cbl.user.firstdeaktivation=Number(WO.adblock.cbl.user.firstdeaktivation)),WO.adblock.cbl.user.lastdeaktivation=localStorage.getItem("cbl_user_lastdeaktivation"),null!=WO.adblock.cbl.user.lastdeaktivation&&(WO.adblock.cbl.user.lastdeaktivation=Number(WO.adblock.cbl.user.lastdeaktivation)),WO.adblock.cbl.user.deactivations=localStorage.getItem("cbl_user_deaktivations"),null==WO.adblock.cbl.user.deactivations?(WO.adblock.cbl.user.deactivations=0,localStorage.setItem("cbl_user_deaktivations",WO.adblock.cbl.user.deactivations)):WO.adblock.cbl.user.deactivations=Number(WO.adblock.cbl.user.deactivations),WO.adblock.cbl.user.reactivations=localStorage.getItem("cbl_user_reaktivations"),null==WO.adblock.cbl.user.reactivations?(WO.adblock.cbl.user.reactivations=0,localStorage.setItem("cbl_user_reaktivations",WO.adblock.cbl.user.reactivations)):WO.adblock.cbl.user.reactivations=Number(WO.adblock.cbl.user.reactivations),WO.adblock.cbl.user.reactivation_fp=localStorage.getItem("cbl_user_reaktivation_fp"),null==WO.adblock.cbl.user.reactivation_fp?(WO.adblock.cbl.user.reactivation_fp=0,localStorage.setItem("cbl_user_reaktivation_fp",WO.adblock.cbl.user.reactivation_fp)):WO.adblock.cbl.user.reactivation_fp=Number(WO.adblock.cbl.user.reactivation_fp),WO.adblock.cbl.user.layerSeen=localStorage.getItem("cbl_user_layerseen"),null==WO.adblock.cbl.user.layerSeen?(WO.adblock.cbl.user.layerSeen=0,localStorage.setItem("cbl_user_layerseen",WO.adblock.cbl.user.layerSeen)):WO.adblock.cbl.user.layerSeen=Number(WO.adblock.cbl.user.layerSeen),WO.adblock.cbl.user.visitsWit ...
#   </script>
#   <script>
#    (function (i,s,o,g,r,a,m){i[r]=i[r]||[],i["abtiming"]=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://try.abtasty.com/49effb28e87c0c103054b4f6a76f624c.js","_abtasty");
#   </script>
#  </body>
# </html>

# %% [markdown]
# But the beautifying of the HTML stream is not our final goal of course. The prettified output is just nice to have when you run your methods against the soup. For instance to find out which part of your HTML you targeted with a find(tag) method and which tag to target next to get the desired data. Firstly, however, I would analyze the HTML structure in Chrome's Developer Tool's and make a plan how to access my table elements (the years and the according values). Initially, I found out that the whole table is inside a TABLE tag with the ID 'climatecalculator_result'. With our `soup` object, we now can easily access any element of the DOM with methods like find() by searching for some attribute or anything else:

# %%
climate_frame = soup.find(id='climatecalculator_result')
print(climate_frame.prettify())
# Out:
# <table id="climatecalculator_result">
#  <thead>
#   <tr class="headline">
#    <th colspan="2">
#     Monatsanalyse
#    </th>
#   </tr>
#   <tr class="headline">
#    <th colspan="2">
#     Tageshöchsttemperatur August
#     <br/>
#     Wetterstation Moskau
#    </th>
#   </tr>
#   <tr class="mean">
#    <th>
#     Mittel 1990 - 2017
#    </th>
#    <th>
#     22.3 °C
#    </th>
#   </tr>
#   <tr class="divide">
#    <th colspan="2">
#    </th>
#   </tr>
#   <tr class="detailhead">
#    <th>
#     Jahr
#    </th>
#    <th>
#    </th>
#   </tr>
#  </thead>
#  <tbody>
#   <tr>
#    <td>
#     2017
#    </td>
#    <td>
#     25.4 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2016
#    </td>
#    <td>
#     24.7 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2015
#    </td>
#    <td>
#     22.8 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2014
#    </td>
#    <td>
#     24.9 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2013
#    </td>
#    <td>
#     23.8 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2012
#    </td>
#    <td>
#     22.4 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2011
#    </td>
#    <td>
#     24.1 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2010
#    </td>
#    <td>
#     27.3 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2009
#    </td>
#    <td>
#     20.2 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2008
#    </td>
#    <td>
#     21.7 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2007
#    </td>
#    <td>
#     25.7 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2006
#    </td>
#    <td>
#     21.7 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2005
#    </td>
#    <td>
#     23.1 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2004
#    </td>
#    <td>
#     23.6 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2003
#    </td>
#    <td>
#     21.2 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2002
#    </td>
#    <td>
#     22.7 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     2001
#    </td>
#    <td>
#     21.6 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     2000
#    </td>
#    <td>
#     21.3 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1999
#    </td>
#    <td>
#     21.2 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1998
#    </td>
#    <td>
#     19.3 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1997
#    </td>
#    <td>
#     22.1 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1996
#    </td>
#    <td>
#     - °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1995
#    </td>
#    <td>
#     21.1 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1994
#    </td>
#    <td>
#     19.6 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1993
#    </td>
#    <td>
#     19.2 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1992
#    </td>
#    <td>
#     22.4 °C
#    </td>
#   </tr>
#   <tr>
#    <td>
#     1991
#    </td>
#    <td>
#     19.9 °C
#    </td>
#   </tr>
#   <tr class="odd">
#    <td>
#     1990
#    </td>
#    <td>
#     19.8 °C
#    </td>
#   </tr>
#  </tbody>
# </table>

# %% [markdown]
# Now we have a structure, that we hopefully can work with. So far it looks like the algorithm could be something like
# <code>
# > To your own database:
# > For every row &lt;tr&gt; put the first &lt;td&gt; in column 'year' and the second &lt;td&gt; in column 'highest_temp'
# </code>
# <br>
# After a bit of playing with some simple for loops we can deduct those two simple loops and get the data achieved with the beautifulsoup library again:

# %%
table = climate_frame.tbody # you can access child elements just by using the dot notation
for row in table.findAll('tr'):
    for td in row.find_all('td'):
        print(td.get_text())
# Out:
# 2017
# 25.4 °C
# 2016
# 24.7 °C
# 2015
# 22.8 °C
# 2014
# 24.9 °C
# 2013
# 23.8 °C
# 2012
# 22.4 °C
# 2011
# 24.1 °C
# 2010
# 27.3 °C
# 2009
# 20.2 °C
# 2008
# 21.7 °C
# 2007
# 25.7 °C
# 2006
# 21.7 °C
# 2005
# 23.1 °C
# 2004
# 23.6 °C
# 2003
# 21.2 °C
# 2002
# 22.7 °C
# 2001
# 21.6 °C
# 2000
# 21.3 °C
# 1999
# 21.2 °C
# 1998
# 19.3 °C
# 1997
# 22.1 °C
# 1996
# - °C
# 1995
# 21.1 °C
# 1994
# 19.6 °C
# 1993
# 19.2 °C
# 1992
# 22.4 °C
# 1991
# 19.9 °C
# 1990
# 19.8 °C

# %% [markdown]
# <i>A little side note on legal stuff: when I familiarized myself with web
# scraping (here: https://www.dataquest.io/blog/web-scraping-tutorial-python/), I stumbled over the fact that actually I could theoretically just use the API without scraping anything, but 'luckily' www.wetteronline.de doesn't have an API for historical data :)Funny enough, the dataquest tutorial also uses a weather page for scraping. Another important point here: dataquest uses CURRENT weather data to scrape. This could be problematic with www.wetteronline.de's current/forecasting weather data because they sell this weather data API, so this could be subject to copyright. So keep in mind to stay in conformity with the law especially if you go public with your results (a little intro: http://blog.icreon.us/advise/web-scraping-legality) </i>

# %% [markdown]
# The data above looks good to me now. It should be really easy to put it all in separate columns in a database.
#
# But first we want *all data* for *all months* for *all categories*.
# To do so, we first need to examine the URL more closely:
# http://www.wetteronline.de/?pcid=pc_rueckblick_climate&gid=27612&iid=27612&pid=p_rueckblick_climatecalculator&sid=Default&var=TX&analysis=monthly&month=08&startyear=1990&endyear=2017&iid=27612
#
# Let's see how to divide this long peace of art into some readable chunks:
# <br>
# http://www.wetteronline.de/
# <br>
# ?
# <br>
# pcid=pc_rueckblick_climate
# <br>
# &
# <br>
# gid=27612
# <br>
# &
# <br>
# iid=27612
# <br>
# &
# <br>
# pid=p_rueckblick_climatecalculator
# <br>
# &
# <br>
# sid=Default
# <br>
# &
# <br>
# var=TX
# <br>
# &
# <br>
# analysis=monthly
# <br>
# &
# <br>
# month=08
# <br>
# &
# <br>
# startyear=1990
# <br>
# &
# <br>
# endyear=2017
# <br>
# &
# <br>
# iid=27612
# <br>

# %% [markdown]
# If we play around with the form at http://www.wetteronline.de/klimarechner/berlin, we can quickly figure out that to get ALL data we have to change var=TX for the according category codes and month=08. But before I apply my theories to a real database, I like to verify them with some plain print outs. This would also be the final code for the whole scraping exercise:

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs

months = ['01','02','03','04','05','06','07','08','09','10','11','12']
categories = ['TX','TN','NS','FFkmh']

print('this is just a little part of the whole output \n comment out the if parts of the code to have the full outprint')

for category in categories:
    for month in months:
        url = 'http://www.wetteronline.de/?pcid=pc_rueckblick_climate&gid=10382&iid=10382&pid=p_rueckblick_climatecalculator&sid=Default&var=' + category + '&analysis=monthly&month=' + month + '&startyear=1990&endyear=2017&iid=10382'
        req = Request(url,
                      headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        webpage = webpage.decode('utf-8')
        soup = bs(webpage, 'html.parser')
        table = soup.tbody
        if(category is 'TX' and month is '01'):
            print('\nCategory    Month\n' + category + '          ' + month + '\n')
        for row in table.findAll('tr'):
            for td in row.find_all("td"):
                if(category is 'TX' and month is '01'):
                    print(td.get_text())
# Out:
# this is just a little part of the whole output
#  comment out the if parts of the code to have the full outprint
#
# Category    Month
# TX          01
#
# 2017
# 1.3 °C
# 2016
# 2.2 °C
# 2015
# 5.0 °C
# 2014
# 2.9 °C
# 2013
# 1.9 °C
# 2012
# 4.0 °C
# 2011
# 3.5 °C
# 2010
# -3.1 °C
# 2009
# 0.7 °C
# 2008
# 6.2 °C
# 2007
# 7.6 °C
# 2006
# -0.6 °C
# 2005
# 5.2 °C
# 2004
# 1.2 °C
# 2003
# 2.2 °C
# 2002
# 4.5 °C
# 2001
# 3.4 °C
# 2000
# 3.7 °C
# 1999
# 5.9 °C
# 1998
# 5.5 °C
# 1997
# 0.4 °C
# 1996
# -1.9 °C
# 1995
# 2.9 °C
# 1994
# 5.3 °C
# 1993
# 4.9 °C
# 1992
# 3.3 °C
# 1991
# 4.7 °C
# 1990
# 5.9 °C

# %% [markdown]
# # Conclusion
# This is why I love Python: you can have a bunch of data in your pocket from a website with a few lines of code.
# Thanks for staying by! By now we have achieved scraping all average data of all categories for all months and all historical years down to 1990.
#
# # What's next?
# Next I will continue with setting up a database, push the data into it and start to compare and analyze it using different statistical approaches including data visualization. Any feedback is always welcome, especially to figure out how good this step by step format works for you folks.
